# %%
class Solution:
    def findNumbers(self, nums: list[int]) -> int:
        count = 0
        return sum([1 for i in nums if len(str(i))%2==0])

# %%
run = Solution()

# %%
run.findNumbers([1,12,123,1234])
# Out:
# 2
