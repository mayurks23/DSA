# %%
class Solution:
    def xorOperation(self, n: int, start: int) -> int:
        nums = []
        result = start
        for i in range(1,n):
            result ^= (start + 2 * i)
        return result

# %%
run = Solution()

# %%
run.xorOperation(4,3)
# Out:
# 8
